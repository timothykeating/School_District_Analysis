# %%
# Dependencies and Setup
import pandas as pd


# File to Load (Remember to change the path if needed.)
school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

# Read the School Data and Student Data and store into a Pandas DataFrame
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# Cleaning Student Names and Replacing Substrings in a Python String
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# Iterate through the words in the "prefixes_suffixes" list and replace them with an empty space, "".
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")

# Check names.
student_data_df
# Out:
# C:\Users\timot\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: The default value of regex will change from True to False in a future version.
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# ...

# %% [markdown]
# ## Deliverable 1: Replace the reading and math scores.
#
# ### Replace the 9th grade reading and math scores at Thomas High School with NaN.

# %%
# Install numpy using conda install numpy or pip install numpy. 
# Step 1. Import numpy as np.
import numpy as np

# %%
# Step 2. Use the loc method on the student_data_df to select all the reading scores from the 9th grade at Thomas High School and replace them with NaN.
student_data_df.loc[(student_data_df['school_name']=='Thomas High School') & (student_data_df['grade']=='9th'),['reading_score']]=np.nan

# student_data_df

# %%
#  Step 3. Refactor the code in Step 2 to replace the math scores with NaN.
student_data_df.loc[(student_data_df['school_name']=='Thomas High School') & (student_data_df['grade']=='9th'),['math_score']]=np.nan

# student_data_df

# %%
#  Step 4. Check the student data for NaN's. 

student_data_df.tail(30)
# Out:
#        Student ID         student_name gender grade         school_name  \
# 39140       39140   Cheyenne Hernandez      F   9th  Thomas High School
# 39141       39141    Jonathan Sullivan      M  10th  Thomas High School
# 39142       39142      Deborah Higgins      F  10th  Thomas High School
# 39143       39143       Steven Jackson      M  11th  Thomas High School
# 39144       39144     Cristian Webster      M  12th  Thomas High School
# 39145       39145           Audrey Fry      F  10th  Thomas High School
# 39146       39146      Michael Carroll      M   9th  Thomas High School
# 39147       39147      Raymond Hawkins      M  10th  Thomas High School
# 39148       39148   Christopher Wilson      M  10th  Thomas High School
# 39149       39149      Glenda Fletcher      F  11th  Thomas High School
# 39150       39150    Jennifer Hamilton      F  11th  Thomas High School
# 39151       39151     Shannon Williams      F  10th  Thomas High School
# ...

# %% [markdown]
# ## Deliverable 2 : Repeat the school district analysis

# %% [markdown]
# ### District Summary

# %%
# Combine the data into a single dataset
school_data_complete_df = pd.merge(student_data_df, school_data_df, how="left", on=["school_name", "school_name"])
# school_data_complete_df.head()

# %%
# Calculate the Totals (Schools and Students)
school_count = len(school_data_complete_df["school_name"].unique())
student_count = school_data_complete_df["Student ID"].count()

# Calculate the Total Budget
total_budget = school_data_df["budget"].sum()

# %%
# Calculate the Average Scores using the "clean_student_data".
average_reading_score = school_data_complete_df["reading_score"].mean()
average_math_score = school_data_complete_df["math_score"].mean()

# %%
# Step 1. Get the number of students that are in ninth grade at Thomas High School.
# These students have no grades. 
thomas9graders=student_data_df.loc[(student_data_df['school_name']=='Thomas High School') & (student_data_df['grade']=='9th'),['Student ID']].count()
# thomas9graders

# Get the total student count 
student_count = school_data_complete_df["Student ID"].count()
# student_count

# Step 2. Subtract the number of students that are in ninth grade at 
# Thomas High School from the total student count to get the new total student count.

new_count=student_count-thomas9graders
# new_count

# %%
# Calculate the passing rates using the "clean_student_data".
passing_math_count = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)].count()["student_name"]
passing_reading_count = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)].count()["student_name"]

# %%
# Step 3. Calculate the passing percentages with the new total student count.
new_math_pct=(passing_math_count/new_count)*100
new_read_pct=(passing_reading_count/new_count)*100
# new_math_pct

# %%
# Calculate the students who passed both reading and math.
passing_math_reading = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)
                                               & (school_data_complete_df["reading_score"] >= 70)]

# Calculate the number of students that passed both reading and math.
overall_passing_math_reading_count = passing_math_reading["student_name"].count()


# Step 4.Calculate the overall passing percentage with new total student count.
new_oall_pct=(overall_passing_math_reading_count/new_count)*100
# new_oall_pct

# %%
# Create a DataFrame
district_summary_df = pd.DataFrame(
         {"Total Schools": school_count, 
          "Total Students": new_count, 
          "Total Budget": total_budget,
          "Average Math Score": average_math_score, 
          "Average Reading Score": average_reading_score,
          "% Passing Math": new_math_pct,
         "% Passing Reading": new_read_pct,
        "% Overall Passing": new_oall_pct})
# district_summary_df



# Format the "Total Students" to have the comma for a thousands separator.
district_summary_df["Total Students"] = district_summary_df["Total Students"].map("{:,}".format)
# Format the "Total Budget" to have the comma for a thousands separator, a decimal separator and a "$".
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("${:,.2f}".format)
# Format the columns.
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:.1f}".format)
district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:.1f}".format)
district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].map("{:.1f}".format)
district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].map("{:.1f}".format)
district_summary_df["% Overall Passing"] = district_summary_df["% Overall Passing"].map("{:.1f}".format)

# Display the data frame
district_summary_df
# Out:
#             Total Schools Total Students    Total Budget Average Math Score  \
# Student ID             15         38,709  $24,649,428.00               78.9
#
#            Average Reading Score % Passing Math % Passing Reading  \
# Student ID                  81.9           74.8              85.7
#
#            % Overall Passing
# Student ID              64.9

# %% [markdown]
# ##  School Summary

# %%
# Determine the School Type
per_school_types = school_data_df.set_index(["school_name"])["type"]

# Calculate the total student count.
per_school_counts = school_data_complete_df["school_name"].value_counts()

# Calculate the total school budget and per capita spending
per_school_budget = school_data_complete_df.groupby(["school_name"]).mean()["budget"]
# Calculate the per capita spending.
per_school_capita = per_school_budget / per_school_counts

# Calculate the average test scores.
per_school_math = school_data_complete_df.groupby(["school_name"]).mean()["math_score"]
per_school_reading = school_data_complete_df.groupby(["school_name"]).mean()["reading_score"]

# Calculate the passing scores by creating a filtered DataFrame.
per_school_passing_math = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)]
per_school_passing_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)]

# Calculate the number of students passing math and passing reading by school.
per_school_passing_math = per_school_passing_math.groupby(["school_name"]).count()["student_name"]
per_school_passing_reading = per_school_passing_reading.groupby(["school_name"]).count()["student_name"]

# Calculate the percentage of passing math and reading scores per school.
per_school_passing_math = per_school_passing_math / per_school_counts * 100
per_school_passing_reading = per_school_passing_reading / per_school_counts * 100

# Calculate the students who passed both reading and math.
per_passing_math_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)
                                               & (school_data_complete_df["math_score"] >= 70)]

# Calculate the number of students passing math and passing reading by school.
per_passing_math_reading = per_passing_math_reading.groupby(["school_name"]).count()["student_name"]

# Calculate the percentage of passing math and reading scores per school.
per_overall_passing_percentage = per_passing_math_reading / per_school_counts * 100

# %%
# Create the DataFrame
per_school_summary_df = pd.DataFrame({
    "School Type": per_school_types,
    "Total Students": per_school_counts,
    "Total School Budget": per_school_budget,
    "Per Student Budget": per_school_capita,
    "Average Math Score": per_school_math,
    "Average Reading Score": per_school_reading,
    "% Passing Math": per_school_passing_math,
    "% Passing Reading": per_school_passing_reading,
    "% Overall Passing": per_overall_passing_percentage})


# per_school_summary_df.head()

# %%
# Format the Total School Budget and the Per Student Budget
per_school_summary_df["Total School Budget"] = per_school_summary_df["Total School Budget"].map("${:,.2f}".format)
per_school_summary_df["Per Student Budget"] = per_school_summary_df["Per Student Budget"].map("${:,.2f}".format)

# Display the data frame
per_school_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %%
# Step 5.  Get the number of 10th-12th graders from Thomas High School (THS).
thomas1012graders=student_data_df.loc[(student_data_df['school_name']=='Thomas High School') & (student_data_df['grade']!='9th'),['Student ID']].count()
# thomas1012graders

# %%
# Step 6. Get all the students passing math from THS
pass_math_t1012g=student_data_df.loc[(student_data_df['school_name']=='Thomas High School') & (student_data_df['math_score']>=70)].count()['student_name']
# pass_math_t1012g

# %%
# Step 7. Get all the students passing reading from THS
pass_read_t1012g=student_data_df.loc[(student_data_df['school_name']=='Thomas High School') & (student_data_df['reading_score']>=70)].count()['student_name']
# pass_read_t1012g

# %%
# Step 8. Get all the students passing math and reading from THS
pass_both_t1012g=student_data_df.loc[(student_data_df['school_name']=='Thomas High School') & (student_data_df['math_score']>=70) & (student_data_df['reading_score']>=70)].count()['student_name']
# pass_both_t1012g

# %%
# Step 9. Calculate the percentage of 10th-12th grade students passing math from Thomas High School. 
pct_math_t1012g=(pass_math_t1012g/thomas1012graders)*100
# pct_math_t1012g

# %%
# Step 10. Calculate the percentage of 10th-12th grade students passing reading from Thomas High School.
pct_read_t1012g=(pass_read_t1012g/thomas1012graders)*100
# pct_read_t1012g

# %%
# Step 11. Calculate the overall passing percentage of 10th-12th grade from Thomas High School. 
pct_both_t1012g=(pass_both_t1012g/thomas1012graders)*100
# pct_both_t1012g

# %%
# Step 12. Replace the passing math percent for Thomas High School in the per_school_summary_df.
per_school_summary_df.iloc[-3,-3]=pct_math_t1012g
# per_school_summary_df

# %%
# Step 13. Replace the passing reading percentage for Thomas High School in the per_school_summary_df.
per_school_summary_df.iloc[-3,-2]=pct_read_t1012g
# per_school_summary_df

# %%
# Step 14. Replace the overall passing percentage for Thomas High School in the per_school_summary_df.
per_school_summary_df.iloc[-3,-1]=pct_both_t1012g
# per_school_summary_df

# %%
per_school_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %% [markdown]
# ## High and Low Performing Schools

# %%
# Sort and show top five schools.
per_school_summary_df=per_school_summary_df.sort_values(['% Overall Passing'],ascending=False)
per_school_summary_df.head()
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.350937
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
# Sort and show BOTTOM five schools.
per_school_summary_df=per_school_summary_df.sort_values(['% Overall Passing'],ascending=True)
per_school_summary_df.head()
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %% [markdown]
# ## Math and Reading Scores by Grade

# %%
# Create a DataFrame of scores by grade level using conditionals.
glm=school_data_complete_df.groupby(['grade']).mean()['math_score']
glr=school_data_complete_df.groupby(['grade']).mean()['reading_score']

glcom=pd.DataFrame(
{'Ave Math Score per Grade':glm,
'Ave Reading Score per Grade':glr
})

glcom
# Out:
#        Ave Math Score per Grade  Ave Reading Score per Grade
# grade
# 10th                  78.941483                    81.874410
# 11th                  79.083548                    81.885714
# 12th                  78.993164                    81.819851
# 9th                   78.739655                    81.837946

# %%
# Group each grade level DataFrame by the school name for the average math score.
gl_math=school_data_complete_df.groupby(['school_name','grade']).mean()['math_score']

glmath_df=pd.DataFrame({'Ave Math Score by School, per Grade Level':gl_math})
glmath_df
# Out:
#                              Ave Math Score by School, per Grade Level
# school_name           grade
# Bailey High School    10th                                   76.996772
#                       11th                                   77.515588
#                       12th                                   76.492218
#                       9th                                    77.083676
# Cabrera High School   10th                                   83.154506
#                       11th                                   82.765560
#                       12th                                   83.277487
#                       9th                                    83.094697
# Figueroa High School  10th                                   76.539974
#                       11th                                   76.884344
#                       12th                                   77.151369
#                       9th                                    76.403037
# ...

# %%
# Group each grade level DataFrame by the school name for the average reading score.
gl_read=school_data_complete_df.groupby(['school_name','grade']).mean()['reading_score']
glread_df=pd.DataFrame({'Ave Reading Score by School, per Grade Level':gl_read})
glread_df
# Out:
#                              Ave Reading Score by School, per Grade Level
# school_name           grade
# Bailey High School    10th                                      80.907183
#                       11th                                      80.945643
#                       12th                                      80.912451
#                       9th                                       81.303155
# Cabrera High School   10th                                      84.253219
#                       11th                                      83.788382
#                       12th                                      84.287958
#                       9th                                       83.676136
# Figueroa High School  10th                                      81.408912
#                       11th                                      80.640339
#                       12th                                      81.384863
# ...

# %%
################################################################
################################################################
################################################################

# %%
# Combine each grade level Series for average math scores into a single DataFrame.
#
#
#[TK Says] - I think I did this already - I do not understand the ask here....

# %%
# Combine each grade level Series for average reading scores into a single DataFrame.
#
#
#[TK Says] - I think I did this already - I do not understand the ask here....

# %%
################################################################
################################################################
################################################################

# %%
# Format each grade column.
glmath_df['Ave Math Score by School, per Grade Level']=glmath_df['Ave Math Score by School, per Grade Level'].map('{:.1f}'.format)
glmath_df.head(2)
# Out:
#                          Ave Math Score by School, per Grade Level
# school_name        grade
# Bailey High School 10th                                       77.0
#                    11th                                       77.5

# %%
glread_df['Ave Reading Score by School, per Grade Level']=glread_df['Ave Reading Score by School, per Grade Level'].map('{:.1f}'.format)
glread_df.head(2)
# Out:
#                          Ave Reading Score by School, per Grade Level
# school_name        grade
# Bailey High School 10th                                          80.9
#                    11th                                          80.9

# %%
#
#
# [TK Says] - I am going to combined the two DataFrames that I have so everything is on one table
#
#
#
#
gl_sch_comb_df=pd.DataFrame(
{'Ave Math Score by School, per Grade Level':gl_math,
'Ave Reading Score by School, per Grade Level':gl_read})

gl_sch_comb_df['Ave Math Score by School, per Grade Level']=gl_sch_comb_df['Ave Math Score by School, per Grade Level'].map('{:.1f}'.format)
gl_sch_comb_df['Ave Reading Score by School, per Grade Level']=gl_sch_comb_df['Ave Reading Score by School, per Grade Level'].map('{:.1f}'.format)




# Display the data frame
gl_sch_comb_df
# Out:
#                             Ave Math Score by School, per Grade Level  \
# school_name           grade
# Bailey High School    10th                                       77.0
#                       11th                                       77.5
#                       12th                                       76.5
#                       9th                                        77.1
# Cabrera High School   10th                                       83.2
#                       11th                                       82.8
#                       12th                                       83.3
#                       9th                                        83.1
# Figueroa High School  10th                                       76.5
#                       11th                                       76.9
#                       12th                                       77.2
#                       9th                                        76.4
# ...

# %% [markdown]
# ## Scores by School Spending

# %%
# Establish the spending bins and group names.
bud_bins=[0,585,630,645,675]

bin_names=['<$584','$585-$629','$630-$644','$645-$675']

# Categorize spending based on the bins.
per_school_capita.groupby(pd.cut(per_school_capita,bud_bins)).count()
# Out:
# (0, 585]      4
# (585, 630]    4
# (630, 645]    4
# (645, 675]    3
# dtype: int64

# %%
#add a column to the summary DF to show the bin assignment
per_school_summary_df['Budget Bin']=pd.cut(per_school_capita,bud_bins,labels=bin_names)
# per_school_summary_df.head()

# %%
# Calculate averages for the desired columns. 
ave_math_group = per_school_summary_df.groupby(['Budget Bin']).mean()['Average Math Score']
ave_read_group = per_school_summary_df.groupby(['Budget Bin']).mean()['Average Reading Score']
ave_passmath_group = per_school_summary_df.groupby(['Budget Bin']).mean()['% Passing Math']
ave_passread_group = per_school_summary_df.groupby(['Budget Bin']).mean()['% Passing Reading']
ave_overall_group = per_school_summary_df.groupby(['Budget Bin']).mean()['% Overall Passing']

# %%
# Create the DataFrame
budget_df=pd.DataFrame({
'Average Math Score':ave_math_group,
'Average Reading Score':ave_read_group,
'% Passing Math':ave_passmath_group,
'% Passing Reading':ave_passread_group,
'% Overall Passing':ave_overall_group})

# budget_df

# %%
# Format the DataFrame 
budget_df['Average Math Score']=budget_df['Average Math Score'].map('{:.1f}'.format)
budget_df['Average Reading Score']=budget_df['Average Reading Score'].map('{:.1f}'.format)
budget_df['% Passing Math']=budget_df['% Passing Math'].map('{:.0f}'.format)
budget_df['% Passing Reading']=budget_df['% Passing Reading'].map('{:.0f}'.format)
budget_df['% Overall Passing']=budget_df['% Overall Passing'].map('{:.0f}'.format)

budget_df
# Out:
#            Average Math Score Average Reading Score % Passing Math  \
# Budget Bin
# <$584                    83.5                  83.9             93
# $585-$629                81.9                  83.2             87
# $630-$644                78.5                  81.6             73
# $645-$675                77.0                  81.0             66
#
#            % Passing Reading % Overall Passing
# Budget Bin
# <$584                     97                90
# $585-$629                 93                81
# $630-$644                 84                63
# $645-$675                 81                54

# %% [markdown]
# ## Scores by School Size

# %%
# Establish the bins.

size_bins=[0,1500,1850,2800,4000,5000]

size_names=['Less than 1500','1500-1849','1850-2799','2800-3999','4000-4999']

# Categorize spending based on the bins.
per_school_counts.groupby(pd.cut(per_school_counts,size_bins)).count()
# Out:
# school_name
# (0, 1500]       3
# (1500, 1850]    3
# (1850, 2800]    3
# (2800, 4000]    3
# (4000, 5000]    3
# Name: school_name, dtype: int64

# %%
#add a column to the summary DF to show the bin assignment
per_school_summary_df['Size Bin']=pd.cut(per_school_counts,size_bins,labels=size_names)
# per_school_summary_df.head()

# %%
# Calculate averages for the desired columns. 
sizeave_math_group = per_school_summary_df.groupby(['Size Bin']).mean()['Average Math Score']
sizeave_read_group = per_school_summary_df.groupby(['Size Bin']).mean()['Average Reading Score']
sizeave_passmath_group = per_school_summary_df.groupby(['Size Bin']).mean()['% Passing Math']
sizeave_passread_group = per_school_summary_df.groupby(['Size Bin']).mean()['% Passing Reading']
sizeave_overall_group = per_school_summary_df.groupby(['Size Bin']).mean()['% Overall Passing']

# %%
# Assemble into DataFrame. 
size_df=pd.DataFrame({
'Average Math Score':sizeave_math_group,
'Average Reading Score':sizeave_read_group,
'% Passing Math':sizeave_passmath_group,
'% Passing Reading':sizeave_passread_group,
'% Overall Passing':sizeave_overall_group})

# size_df

# %%
# Format the DataFrame  
size_df['Average Math Score']=size_df['Average Math Score'].map('{:.1f}'.format)
size_df['Average Reading Score']=size_df['Average Reading Score'].map('{:.1f}'.format)
size_df['% Passing Math']=size_df['% Passing Math'].map('{:.0f}'.format)
size_df['% Passing Reading']=size_df['% Passing Reading'].map('{:.0f}'.format)
size_df['% Overall Passing']=size_df['% Overall Passing'].map('{:.0f}'.format)

size_df
# Out:
#                Average Math Score Average Reading Score % Passing Math  \
# Size Bin
# Less than 1500               83.7                  83.9             93
# 1500-1849                    83.5                  83.9             93
# 1850-2799                    81.1                  82.9             85
# 2800-3999                    76.7                  81.0             66
# 4000-4999                    77.1                  81.0             66
#
#                % Passing Reading % Overall Passing
# Size Bin
# Less than 1500                96                90
# 1500-1849                     96                90
# 1850-2799                     91                79
# 2800-3999                     81                53
# 4000-4999                     81                54

# %% [markdown]
# ## Scores by School Type

# %%
# Calculate averages for the desired columns. 
typeave_math_group = per_school_summary_df.groupby(['School Type']).mean()['Average Math Score']
typeave_read_group = per_school_summary_df.groupby(['School Type']).mean()['Average Reading Score']
typeave_passmath_group = per_school_summary_df.groupby(['School Type']).mean()['% Passing Math']
typeave_passread_group = per_school_summary_df.groupby(['School Type']).mean()['% Passing Reading']
typeave_overall_group = per_school_summary_df.groupby(['School Type']).mean()['% Overall Passing']

# %%
# Assemble into DataFrame. 
type_bins_df=pd.DataFrame({
    'Ave Math Score':typeave_math_group,
    'Ave Reading Score':typeave_read_group,
    '% Passing Math':typeave_passmath_group,
    '% Passing Reading':typeave_passread_group,
    '% Overall Passing':typeave_overall_group
})


# type_bins_df

# %%
# # Format the DataFrame 
type_bins_df['Ave Math Score']=type_bins_df['Ave Math Score'].map('{:.1f}'.format)
type_bins_df['Ave Reading Score']=type_bins_df['Ave Reading Score'].map('{:.1f}'.format)
type_bins_df['% Passing Math']=type_bins_df['% Passing Math'].map('{:.0f}'.format)
type_bins_df['% Passing Reading']=type_bins_df['% Passing Reading'].map('{:.0f}'.format)
type_bins_df['% Overall Passing']=type_bins_df['% Overall Passing'].map('{:.0f}'.format)

type_bins_df
# Out:
#             Ave Math Score Ave Reading Score % Passing Math % Passing Reading  \
# School Type
# Charter               83.5              83.9             94                97
# District              77.0              81.0             67                81
#
#             % Overall Passing
# School Type
# Charter                    90
# District                   54
